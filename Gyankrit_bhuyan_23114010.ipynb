# %% [markdown]
# <a href="https://colab.research.google.com/github/gyanLM10/gyanLM10/blob/main/Gyankrit_bhuyan_23114010.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/.config/configurations/Airline_satisfaction.csv')

# %%
df.head()
# Out:
#    ID  Gender Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male  48    First-time       Business  Business            821.0
# 1   2  Female  35     Returning       Business  Business            821.0
# 2   3    Male  41     Returning       Business  Business            853.0
# 3   4    Male  50     Returning       Business  Business           1905.0
# 4   5  Female  49     Returning       Business  Business           3470.0
#
#    Departure Delay Arrival Delay  Departure and Arrival Time Convenience  ...  \
# 0                2           5.0                                     3.0  ...
# 1               26          39.0                                     2.0  ...
# 2                0           0.0                                     4.0  ...
# 3                0           0.0                                     2.0  ...
# 4                0           1.0                                     3.0  ...
#
# ...

# %%
new_df = df['Satisfaction'].value_counts().rename_axis('sub_sat').reset_index(name='counts')
new_df.head(2)
# Out:
#                    sub_sat  counts
# 0  Neutral or Dissatisfied   79418
# 1                Satisfied   60846
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_28['counts'].plot(kind='hist', bins=20, title='counts')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_29.groupby('sub_sat').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
yrlabels = new_df.sub_sat
yrvalues = new_df.counts

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
ax.pie(yrvalues, labels = yrlabels, autopct = '%1.2f%%')
plt.show()

# %%
df.head()
# Out:
#    ID  Gender Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male  48    First-time       Business  Business            821.0
# 1   2  Female  35     Returning       Business  Business            821.0
# 2   3    Male  41     Returning       Business  Business            853.0
# 3   4    Male  50     Returning       Business  Business           1905.0
# 4   5  Female  49     Returning       Business  Business           3470.0
#
#    Departure Delay Arrival Delay  Departure and Arrival Time Convenience  ...  \
# 0                2           5.0                                     3.0  ...
# 1               26          39.0                                     2.0  ...
# 2                0           0.0                                     4.0  ...
# 3                0           0.0                                     2.0  ...
# 4                0           1.0                                     3.0  ...
#
# ...

# %%
from scipy.stats import chi2_contingency

# %%
cross_tab=pd.crosstab(index=df['Customer Type'],columns=df['Satisfaction'])
cross_tab
# Out:
# Satisfaction   Neutral or Dissatisfied  Satisfied
# Customer Type
# First-time                       18080       5700
# Returning                        55372      50728

# %%
print(type(sns.catplot))
if not callable(sns.catplot):
  raise TypeError("sns is not callable")
# Out:
# <class 'function'>

# %%
from sklearn.preprohcessing import OrdinalEncoder
encoder = OrdinalEncoder()
df.Satisfaction = encoder.fit_transform(df.Satisfaction.values.reshape(-1,1))
df.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2            5.0                                       3
# 1               26           39.0                                       2
# 2                0            0.0                                       4
# 3                0            0.0                                       2
# 4                0            1.0                                       3
#
# ...

# %%
sns.catplot(x="Customer Type",y="Satisfaction", data=df ,  jitter=False)
plt.show()

# %% [markdown]
# same can be done with travel type

# %% [markdown]
# for no 2 we can create pie chart using the same matplotlib function as no

# %%
df.head()
# Out:
#    ID  Gender Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male  48    First-time       Business  Business            821.0
# 1   2  Female  35     Returning       Business  Business            821.0
# 2   3    Male  41     Returning       Business  Business            853.0
# 3   4    Male  50     Returning       Business  Business           1905.0
# 4   5  Female  49     Returning       Business  Business           3470.0
#
#    Departure Delay Arrival Delay  Departure and Arrival Time Convenience  ...  \
# 0                2           5.0                                     3.0  ...
# 1               26          39.0                                     2.0  ...
# 2                0           0.0                                     4.0  ...
# 3                0           0.0                                     2.0  ...
# 4                0           1.0                                     3.0  ...
#
# ...

# %%
df2=df.loc[(df['Gender'] == 'Male')& (df['Customer Type'] =='First-time')]
df2.head()
# Out:
#     ID Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0    1   Male   48    First-time       Business  Business              821
# 12  13   Male   24    First-time       Business   Economy              453
# 30  31   Male   35    First-time       Business  Business              212
# 31  32   Male   21    First-time       Business   Economy              173
# 46  47   Male   24    First-time       Business  Business              108
#
#     Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                 2            5.0                                       3
# 12               16           30.0                                       2
# 30                0            0.0                                       2
# 31                0            0.0                                       0
# 46                0            0.0                                       4
#
# ...

# %%
df2.describe()
# Out:
#                   ID  Flight Distance  Departure Delay  \
# count   11794.000000     11794.000000     11794.000000
# mean    62083.399356       709.374173        15.665254
# std     37618.456938       492.592081        39.426696
# min         1.000000        67.000000         0.000000
# 25%     27768.750000       347.000000         0.000000
# 50%     59764.500000       594.000000         0.000000
# 75%     94778.000000       957.000000        13.000000
# max    129870.000000      4963.000000       921.000000
#
#        Departure and Arrival Time Convenience  Ease of Online Booking  \
# count                            11794.000000            11794.000000
# mean                                 2.400797                2.720705
# std                                  1.598896                1.334054
# min                                  0.000000                0.000000
# 25%                                  1.000000                2.000000
# ...

# %%
df2.describe(include = 'all')
# Out:
#                    ID Gender           Age Customer Type Type of Travel  \
# count    10937.000000  10937  10937.000000         10937          10937
# unique            NaN      1           NaN             1              2
# top               NaN   Male           NaN    First-time       Business
# freq              NaN  10937           NaN         10937          10835
# mean     64921.153881    NaN     30.249337           NaN            NaN
# std      37609.841473    NaN     11.140344           NaN            NaN
# min          1.000000    NaN      7.000000           NaN            NaN
# 25%      32428.000000    NaN     23.000000           NaN            NaN
# 50%      64828.000000    NaN     27.000000           NaN            NaN
# 75%      97724.000000    NaN     37.000000           NaN            NaN
# max     129870.000000    NaN     85.000000           NaN            NaN
#
#           Class  Flight Distance  Departure Delay  Arrival Delay  \
# ...

# %% [markdown]
# mean age is 30.24

# %% [markdown]
# same can be done for female

# %%
df.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2            5.0                                       3
# 1               26           39.0                                       2
# 2                0            0.0                                       4
# 3                0            0.0                                       2
# 4                0            1.0                                       3
#
# ...

# %%
df3=df.loc[(df['Departure Delay'] > 0) & (df['Arrival Delay'] == 0)]
df3.head()
# Out:
#     ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 9   10  Female   38     Returning       Business  Business             2822
# 19  20  Female   42     Returning       Personal   Economy              821
# 58  59  Female   41     Returning       Business  Business             3997
# 86  87    Male   65     Returning       Personal   Economy               67
# 87  88  Female   52     Returning       Personal   Economy               67
#
#     Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 9                13            0.0                                       2
# 19                4            0.0                                       3
# 58                1            0.0                                       1
# 86                1            0.0                                       5
# 87                2            0.0                                       5
#
# ...

# %%
df3.shape
# Out:
# (13648, 24)

# %% [markdown]
# 13648

# %%
df.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2            5.0                                       3
# 1               26           39.0                                       2
# 2                0            0.0                                       4
# 3                0            0.0                                       2
# 4                0            1.0                                       3
#
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
onehot=OneHotEncoder(dtype='int')
n = pd.DataFrame(onehot.fit_transform([['Satisfaction','Gender','Customer','Type of Travel','Class']])
.toarray())
print(n)
# Out:
#    0  1  2  3  4
# 0  1  1  1  1  1

# %%
df4 = df['Class'].value_counts()
df4.head(2)
# Out:
# Class
# Business    62160
# Economy     58309
# Name: count, dtype: int64

# %%
n.head()
# Out:
#    0  1  2  3  4
# 0  1  1  1  1  1

# %% [markdown]
# the stratgey was to convert the categorical data into numerical using one hot encoder .
# Then we can create heatmap matrix to find the maximum correlation using seaborn library

# %%
df.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2            5.0                                       3
# 1               26           39.0                                       2
# 2                0            0.0                                       4
# 3                0            0.0                                       2
# 4                0            1.0                                       3
#
# ...

# %%
scatter_plot=df.plot.scatter(x="Class", y="Flight Distance",)

# %%
from sklearn.preprocessing import OrdinalEncoder
encoder= OrdinalEncoder()
df['Class'] = encoder.fit_transform(df['Class'].values.reshape(-1,1))
df.head()
# Out:
#    ID  Gender  Age Customer Type  Type of Travel  Class  Flight Distance  \
# 0   1    Male   48    First-time             0.0    0.0              821
# 1   2  Female   35     Returning             0.0    0.0              821
# 2   3    Male   41     Returning             0.0    0.0              853
# 3   4    Male   50     Returning             0.0    0.0             1905
# 4   5  Female   49     Returning             0.0    0.0             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2            5.0                                       3
# 1               26           39.0                                       2
# 2                0            0.0                                       4
# 3                0            0.0                                       2
# 4                0            1.0                                       3
#
#    ...  On-board Service  Seat Comfort  Leg Room Service  Cleanliness  \
# ...

# %%
from scipy.stats import pearsonr
pearsonr(df["Class"],df["Flight Distance"])
# Out:
# PearsonRResult(statistic=-0.4269251563448184, pvalue=0.0)

# %% [markdown]
# since -0.26< 0.5 they are significantly correlated

# %%
plt.figure(figsize=(10,10))
plt.plot(df['Class'],df['Flight Distance'])
plt.show()
